# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.2288, 0.1979, 0.1741],
#         [0.8553, 0.0879, 0.8310],
#         [0.2799, 0.1333, 0.4565],
#         [0.2552, 0.6137, 0.1984],
#         [0.3163, 0.4748, 0.0251]])

# %%
import torch
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 3060 Laptop GPU'
